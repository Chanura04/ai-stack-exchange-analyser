# %% [markdown]
# do some processing

# %%
raw_posts_df=spark.table("default.raw_posts")

# %%
display(raw_posts_df.limit(4))

# %%
import  pyspark.sql.functions as F
from pyspark.sql import DataFrame
from pyspark.sql.types import StructType, StructField, MapType,IntegerType,StringType


def split_tag_into_array(df:DataFrame) -> DataFrame:
    return(
        df
        .withColumn("TagsArray",F.filter(F.split(F.col("tags"), r'\|'),lambda x: x != ""))
        .drop("tags")
    )

def rename_columns(df:DataFrame) -> DataFrame:
    return (
        df.withColumnRenamed("Id","PostId")
    )



def map_post_type(df:DataFrame) -> DataFrame:
    map_df = [
        (1, "Question"),
        (2, "Answer"),
        (3, "Orphaned tag wiki"),
        (4, "Tag wiki excerpt"),
        (5, "Tag wiki"),
        (6, "Moderator nomination"),
        (7, "Wiki placeholder"),
        (8, "Privilege wiki"),
        (9, "Article"),
        (10, "HelpArticle"),
        (12, "Collection"),
        (13, "ModeratorQuestionnaireResponse"),
        (14, "Announcement"),
        (15, "CollectiveDiscussion"),
        (17, "CollectiveCollection")
    ]

    map_schema= StructType([
        StructField("PostTypeId",IntegerType(),False),
        StructField("PostType",StringType(),False)])
    
    map_df = spark.createDataFrame(map_df,schema=map_schema)
    
    return df.join(
        F.broadcast(map_df),
        df["PostTypeId"]==map_df["PostTypeId"],
        "left"
    ).drop(map_df["PostTypeId"])

stg_post_df=(
    raw_posts_df
    .transform(split_tag_into_array)
    .transform(rename_columns)
    .transform(map_post_type)
)

# %%
stg_post_df.explain()

# %%
display(stg_post_df.limit(4))

# %%
from delta.tables import DeltaTable
import pyspark.sql.functions as F

# def incremental_upsert(dest_table:str, df:DataFrame, unique_key:str,update_at:str, full_refresh=False):
#     """
#     Performs incremental upsert using updated_at as the cursor value with unique_key, Doesn't support deletes, very minimal.
#     """
#     if not spark.catalog.tableExists(dest_table) or full_refresh:
#         (
#             df
#             .write
#             .format("delta")
#             .mode("overwrite")
#             .option("overwriteSchema","true")
#             .saveAsTable(dest_table)
#             )
#     else:
#         last_max= (
#             spark.table(dest_table)
#             .agg(F.max(update_at).alias("max_ts"))
#             .collect()[0]["max_ts"]
#         )
#         incremntal_df=df.filter(F.col(update_at)>last_max)

#         if not incremntal_df.rdd.isEmpty():
#             delta_table = DeltaTable.forName(spark, dest_table)
#             (
#                 delta_table.alias("t")
#                     .merge(
#                         source=incremntal_df.alias("s"),
#                         condition= f"s.{unique_key}=t.{unique_key}")
#                     .whenMatchedUpdateAll()
#                     .whenNotMatchedInsertAll()
#                     .execute()
#             )
# dest_table = "default.stg_post"  # target

def incremental_upsert(dest_table: str, df: DataFrame, unique_key: str, update_at: str, full_refresh=False):
    """
    Performs incremental upsert using updated_at as the cursor value with unique_key, Doesn't support deletes, very minimal.
    """
    if not spark.catalog.tableExists(dest_table) or full_refresh:
        (
            df
            .write
            .format("delta")
            .mode("overwrite")
            .option("overwriteSchema", "true")
            .saveAsTable(dest_table)
        )
    else:
        last_max = (
            spark.table(dest_table)
            .agg(F.max(update_at).alias("max_ts"))
            .collect()[0]["max_ts"]
        )
        incremental_df = df.filter(F.col(update_at) > last_max)
        if incremental_df.count() > 0:
            delta_table = DeltaTable.forName(spark, dest_table)
            (
                delta_table.alias("t")
                .merge(
                    source=incremental_df.alias("s"),
                    condition=f"s.{unique_key}=t.{unique_key}"
                )
                .whenMatchedUpdateAll()
                .whenNotMatchedInsertAll()
                .execute()
            )
dest_table ="default.stg_post" #target
incremental_upsert(dest_table, stg_post_df, "PostId", "CreationDate")
    

# incremental_upsert(dest_table, stg_post_df, "PostId", "CreationDate")

# %%
display(spark.table(dest_table).limit(4))

# %%
# spark.table(dest_table).rdd.getNumPartitions()
